# %%
import pandas as pd

data = pd.read_csv('../data/weighted_candidate_data_updated.csv')

data.head()
# Out:
#   Candidate_Location  Distance_From_Job_Location (km) Cost_of_Living_Area  \
# 0             Mumbai                               23              Medium
# 1            Chennai                               17                High
# 2              Delhi                               46              Medium
# 3          Bangalore                               25              Medium
# 4             Mumbai                               41                 Low
#
#         Current_Role Seniority_Level  Experience_Years  Current_Salary (INR)  \
# 0     Data Scientist       Mid-Level                 5               1550739
# 1    Project Manager       Mid-Level                13                791471
# 2  Software Engineer            Lead                14               1946397
# 3  Software Engineer       Mid-Level                14               1310405
# 4  Software Engineer       Mid-Level                10               1636338
#
# ...

# %%
data['Candidate'] = ['C' + str(i) for i in range(1, 5001)]

data = data.sort_values(by='Expected_Joining_Score')

# %%
data.plot.line(x='Candidate', y='Expected_Joining_Score')
# Out:
# <Axes: xlabel='Candidate'>
